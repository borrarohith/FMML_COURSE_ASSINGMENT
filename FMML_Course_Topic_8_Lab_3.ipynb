# %% [markdown]
# <a href="https://colab.research.google.com/github/borrarohith/FMML_COURSE_ASSINGMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-05 03:32:51--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   112MB/s    in 0.6s
#
# 2023-05-05 03:32:57 (112 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 3506 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22071   1410.0555v2  This paper introduces a linear state-space mod...  stat
# 34009   0907.4960v1  Ezhil is a Tamil language based interpreted pr...    cs
# 21568   1102.1204v2  This paper treats the problem of screening for...  stat
# 16918  1707.04412v1  Semantic parsing shines at analyzing complex n...    cs
# 6054   1606.05819v1  We propose a method for building an interpreta...  stat
# ...             ...                                                ...   ...
# 23049  1802.07535v1  We present a novel model architecture which le...  stat
# 30005  1711.04875v2  A novel 3D shape classification scheme, based ...    cs
# 38374  1703.10344v1  Wikipedia entity pages are a valuable source o...    cs
# 22528  1610.08733v1  GPflow is a Gaussian process library that uses...  stat
# 4205   1707.05224v1  In this paper, we address the basic problem of...    cs
#
#                                                    title  year  \
# 22071  Linear State-Space Model with Time-Varying Dyn...  2014
# 34009                Ezhil: A Tamil Programming Language  2009
# 21568                  Large Scale Correlation Screening  2011
# 16918  Evaluating Semantic Parsing against a Simple W...  2017
# 6054   Building an Interpretable Recommender via Loss...  2016
# ...                                                  ...   ...
# 23049  A Generative Deep Recurrent Model for Exchange...  2018
# 30005  3D Shape Classification Using Collaborative Re...  2017
# 38374  Automated News Suggestions for Populating Wiki...  2017
# 22528  GPflow: A Gaussian process library using Tenso...  2016
# 4205   Detection, Recognition and Tracking of Moving ...  2017
#
#                                                 keywords
# 22071  [introduces, dependency, combination, dependen...
# 34009  [interpreted, procedural, programming, represe...
# 21568  [screening, variables, correlations, dimension...
# 16918  [analyzing, composition, computation, question...
# 6054   [interpretable, recommender, personalizing, pr...
# ...                                                  ...
# 23049  [architecture, leverages, inference, dimension...
# 30005  [classification, collaborative, representation...
# 38374  [wikipedia, information, consumption, knowledg...
# 22528  [tensorflow, computations, distinguishing, var...
# 4205   [recognizing, vocabulary, subsequent, initiall...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22071    [introduces, dependency, combination, dependen...
# 34009    [interpreted, procedural, programming, represe...
# 21568    [screening, variables, correlations, dimension...
# 16918    [analyzing, composition, computation, question...
# 6054     [interpretable, recommender, personalizing, pr...
#                                ...
# 6552     [classifiers, corrupted, classifiers, classifi...
# 30947    [boundaries, replicating, functions, memorizat...
# 37980    [optimization, algorithm, applicable, function...
# 12598    [regression, processing, regularization, predi...
# 1751     [representations, variables, beneficial, appli...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8732 words.
# Out of those 4565 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6c6968e4-8309-4594-b590-6d9d7f285ae3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c6968e4-8309-4594-b590-6d9d7f285ae3")) {                    Plotly.newPlot(                        "6c6968e4-8309-4594-b590-6d9d7f285ae3",                        [{"x":["differential","diffusion","outperform","introduces","temperature","evolution","combination","direction","parameters","variational","described","previously","stochastic","dynamical","equations","motivated","introduced","performed","inference","approaches","approximation","dependency","switching","processes","posterior","experiments","continuous","statements","representation","knowledge","available","equivalent","interpreted","programming","languages","constructs","conditional","procedural","implementation","correlation","dimensional","presented","numerical","asymptotic","methodology","phenomenon","influential","distribution","correlated","increases","condition","dimension","overcomes","naturally","tremendous","decreases","thresholds","literature","treatment","application","revealing","discoveries","identifying","persistently","correlations","dominated","applications","expressions","illustrate","screening","variables","threshold","transition","identifies","significant","expression","treatments","comparing","composition","answering","conjunctions","struggles","performance","reasonable","computation","evaluating","analyzing","questions","compositional","investigate","involving","recommended","recommender","classification","minimizing","desirable","algorithms","promotions","customers","responses","historical","preserving","transforms","interpretable","misclassification","transformation","statistics","recognition","effective","different","retrieval","inadequate","aggregating","representations","complementary","detection","outperforms","information","detectors","discriminative","activities","detections","descriptors","empirically","multimedia","represented","significantly","presentation","primitives","particular","conceptualization","construction","expertise","primitive","interface","situations","characterization","reasoning","definition","ontological","distinguishes","represent","framework","attentional","frequencies","approximate","configuration","experimenters","associated","synthetic","restricted","objective","connectivity","algorithm","structure","structures","understood","conjecture","boltzmann","recordings","interactions","interaction","detecting","generalizes","probabilities","statistical","confirmed","hierarchical","comparison","nonparametric","parametric","especially","allocation","including","solutions","dirichlet","polynomial","nonparametrics","flexibility","submodularity","prohibitively","increasingly","promising","specifically","efficient","necessary","descriptor","learnable","activation","conditions","development","computationally","estimation","introduce","demonstrate","sensitive","architecture","connected","confidence","pedestrian"],"y":[28,22,85,79,6,53,125,58,238,60,62,97,123,19,26,62,134,152,210,418,111,45,7,97,44,622,97,17,359,365,320,59,26,132,106,15,105,4,117,74,203,196,68,21,74,18,10,205,28,56,46,63,11,68,11,19,7,103,38,244,8,2,65,1,35,13,425,43,82,7,129,40,43,24,215,63,5,83,37,49,3,1,902,39,142,59,67,60,28,146,44,5,18,520,50,37,619,2,10,28,27,37,13,33,5,58,61,376,271,757,111,9,16,238,30,349,269,667,35,108,38,25,51,65,19,75,293,14,11,270,5,77,12,11,36,44,28,126,47,9,9,121,556,6,16,109,22,2,111,139,59,155,25,840,324,126,24,12,16,11,68,89,62,36,53,163,10,112,142,19,49,121,21,257,142,17,53,0,30,4,7,63,114,158,428,76,34,10,40,133,130,95,208,320,593,65,233,90,31,12],"type":"bar"},{"x":["differential","diffusion","outperform","introduces","temperature","evolution","combin ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4565,), (4565, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Strategies</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4871794871794872);'>Conceptual</span> <span style=''>Change</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.6198704103671708);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>remarkable</span> <span style=''>feature</span> <span style=''>of</span> <span style=''>human</span> <span style=''>beings</span> <span style=''>is</span> <span style=''>their</span> <span style=''>capacity</span> <span style=''>for</span> <span style=''>creative</span> <span style='background-color:rgba(0, 255, 0, 0.41176470588235303);'>behaviour</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>referring</span> <span style=''>to</span> <span style=''>their</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>react</span> <span style=''>to</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>ways</span> <span style=''>that</span> <span style=''>are</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surprising</span> <span style=''>and</span> <span style=''>useful</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Transformational</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>creativity</span> <span style=''>is</span> <span style=''>a</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>creativity</span> <span style=''>where</span> <span style=''>the</span> <span style=''>creative</span> <span style='background-color:rgba(0, 255, 0, 0.41176470588235303);'>behaviour</span> <span style=''>is</span> <span style=''>induced</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3488372093023257);'>transformation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>actors</span> <span style='background-color:rgba(0, 255, 0, 0.4871794871794872);'>conceptual</span> <span style=''>space</span> <span style=''>that</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>representational</span> <span style=''>system</span> <span style=''>with</span> <span style=''>which</span> <span style=''>the</span> <span style=''>actor</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>interprets</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.6447368421052632);'>environment</span> <span style=''>In</span> <span style=''>this</span> <span style=''>report</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>ways</span> <span style=''>of</span> <span style=''>adapting</span> <span style=''>systems</span> <span style=''>of</span> <span style=''>learned</span> <span style='background-color:rgba(0, 255, 0, 0.3112947658402205);'>representations</span> <span style=''>as</span> <span style=''>they</span> <span style=''>switch</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performing</span> <span style=''>one</span> <span style=''>task</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performing</span> <span style=''>another</span> <span style=''>We</span> <span style=''>describe</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.4046345811051694);'>experimental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparison</span> <span style=''>of</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>strategies</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0. ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style=''>Matrix</span> <span style=''>valued</span> <span style=''>Kernel</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>and</span> <span style=''>Granger</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Causality</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style=''>matrix</span> <span style=''>valued</span> <span style=''>multiple</span> <span style=''>kernel</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>problems</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>allows</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>class</span> <span style=''>of</span> <span style=''>mixed</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularizers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>those</span> <span style=''>that</span> <span style=''>induce</span> <span style=''>sparsity</span> <span style=''>to</span> <span style=''>be</span> <span style=''>imposed</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>of</span> <span style=''>vector</span> <span style=''>valued</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reproducing</span> <span style=''>Kernel</span> <span style=''>Hilbert</span> <span style=''>Spaces</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>highly</span> <span style=''>scalable</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigendecomposition</span> <span style=''>free</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>orchestrates</span> <span style=''>two</span> <span style=''>inexact</span> <span style=''>solvers</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>learning</span> <span style=''>both</span> <span style=''>the</span> <span style=''>input</span> <span style=''>and</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separable</span> <span style=''>matrix</span> <span style=''>valued</span> <span style=''>kernels</span> <span style=''>As</span> <span style=''>a</span> <span style=''>key</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>enabled</span> <span style=''>by</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>tasks</span> <span style=''>can</span> <span style=''>be</span> <span style='background-col ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Fast</span> <span style=''>Mixing</span> <span style=''>Models</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structured</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <br/><br/><span style=''>Markov</span> <span style=''>Chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>(MCMC)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>often</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(255, 0, 0, 0.3181818181818182);'>inference</span> <span style=''>inside</span> <span style=''>learning</span> <span style=''>but</span> <span style=''>their</span> <span style=''>slow</span> <span style=''>mixing</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>diagnose</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.44954128440366964);'>approximations</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>seriously</span> <span style=''>degrade</span> <span style=''>learning</span> <span style=''>To</span> <span style='background-color:rgba(0, 255, 0, 0.6190476190476191);'>alleviate</span> <span style=''>these</span> <span style=''>issues</span> <span style=''>we</span> <span style=''>define</span> <span style=''>a</span> <span style=''>new</span> <span style=''>model</span> <span style=''>family</span> <span style=''>using</span> <span style=''>strong</span> <span style=''>Doeblin</span> <span style=''>Markov</span> <span style=''>chains</span> <span style=''>whose</span> <span style=''>mixing</span> <span style=''>times</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precisely</span> <span style='background-color:rgba(0, 255, 0, 0.35135135135135137);'>controlled</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>We</span> <span style=''>also</span> <span style=''>develop</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>such</span> <span style=''>models</span> <span style=''>which</span> <span style=''>involves</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximizing</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3700787401574802);'>likelihood</span> <span style=''>under</span> <span style=''>the</span> <span style=''>induced</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stationary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>these</span> <span style=''>chains</span> <span style=''>We</span> <span style=''>show</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style='background-color:rgba(0, 255, 0, 0.4444444444444445);'>improvements</span> <span style=''>on</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.4830287206266318);'>challenging</span> <span style='background-color:rgba(255, 0, 0, 0.3181818181818182);'>inference</span> <span style=''>tasks</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>from</span> <span style=''>Indirect</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Supervision</span> <span style=''>with</span> <span style=''>Linear</span> <span style=''>Moments</span> <br/><br/><span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>problems</span> <span style=''>where</span> <span style=''>we</span> <span style=''>have</span> <span style=''>indirect</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervision</span> <span style=''>of</span> <span style=''>the</span> <span style=''>output</span> <span style=''>maximum</span> <span style=''>marginal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>faces</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>obstacles</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convexity</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractability</span> <span style=''>of</span> <span style=''>even</span> <span style=''>a</span> <span style=''>single</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>bypass</span> <span style=''>both</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>obstacles</span> <span style=''>for</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style=''>what</span> <span style=''>we</span> <span style=''>call</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>indirectly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>problems</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>simple</span> <span style=''>we</span> <span style=''>solve</span> <span style=''>a</span> <span style=''>linear</span> <span style=''>system</span> <span style=''>to</span> <span style=''>estimate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>which</span> <span style=''>we</span> <span style=''>then</span> <span style=''>use</span> <span style=''>to</span> <span style=''>estimate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>via</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>and</span> <span style=''>show</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>in</span> <span style=''>two</span> <span style=''>settings</span> <span style=''>learning</span> <span style=''>with</span> <span style=''>local</span> <span style=''>privacy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>and</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.13101220387652548)
# 	representation (0.12885857860732233)
# 	architecture (0.083632447954056)
# 	challenging (0.10193826274228285)
# 	segmentation (0.07142857142857142)
# 	experimental (0.1414213926776741)
# 	detection (0.1252692031586504)
# 	different (0.2717157214644652)
# 	recognition (0.1349605168700646)
# 	convolutional (0.13460157932519742)
#
# Some Statistics words are:
# 	statistical (0.14299900695134063)
# 	stochastic (0.13058589870903675)
# 	algorithm (0.38927507447864945)
# 	theoretical (0.15243296921549157)
# 	variables (0.14349553128103276)
# 	estimation (0.17477656405163852)
# 	distribution (0.18570009930486595)
# 	dimensional (0.18867924528301888)
# 	inference (0.2015888778550149)
# 	regression (0.1792452830188679)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="74c93162-0007-4a6e-a797-6dfcda7699a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74c93162-0007-4a6e-a797-6dfcda7699a0")) {                    Plotly.newPlot(                        "74c93162-0007-4a6e-a797-6dfcda7699a0",                        [{"x":["differential","diffusion","outperform","introduces","temperature","evolution","combination","direction","parameters","variational","described","previously","stochastic","dynamical","equations","motivated","introduced","performed","inference","approaches","approximation","dependency","switching","processes","posterior","experiments","continuous","statements","representation","knowledge","available","equivalent","interpreted","programming","languages","constructs","conditional","procedural","implementation","correlation","dimensional","presented","numerical","asymptotic","methodology","phenomenon","influential","distribution","correlated","increases","condition","dimension","overcomes","naturally","tremendous","decreases","thresholds","literature","treatment","application","revealing","discoveries","identifying","persistently","correlations","dominated","applications","expressions","illustrate","screening","variables","threshold","transition","identifies","significant","expression","treatments","comparing","composition","answering","conjunctions","struggles","performance","reasonable","computation","evaluating","analyzing","questions","compositional","investigate","involving","recommended","recommender","classification","minimizing","desirable","algorithms","promotions","customers","responses","historical","preserving","transforms","interpretable","misclassification","transformation","statistics","recognition","effective","different","retrieval","inadequate","aggregating","representations","complementary","detection","outperforms","information","detectors","discriminative","activities","detections","descriptors","empirically","multimedia","represented","significantly","presentation","primitives","particular","conceptualization","construction","expertise","primitive","interface","situations","characterization","reasoning","definition","ontological","distinguishes","represent","framework","attentional","frequencies","approximate","configuration","experimenters","associated","synthetic","restricted","objective","connectivity","algorithm","structure","structures","understood","conjecture","boltzmann","recordings","interactions","interaction","detecting","generalizes","probabilities","statistical","confirmed","hierarchical","comparison","nonparametric","parametric","especially","allocation","including","solutions","dirichlet","polynomial","nonparametrics","flexibility","submodularity","prohibitively","increasingly","promising","specifically","efficient","necessary","descriptor","learnable","activation","conditions","development","computationally","estimation","introduce","demonstrate","sensitive","architecture","connected","confidence","pedestrian","misalignment","generated","competitive","embedding","compromise","integrated","transformations","invariant","pedestrians","variations","identification","conducted","background","alignment","considers","favorably","subsequent","subsequently","guarantee","utilizing","selecting","empirical","subsample","nonetheless","proportional","subsampling","hypothesis","practical","components","estimated","techniques","undersampled","measurements","component","underlying","reconstruction","compressed","spatiotemporal","accelerated","decomposed","extension","estimating","penalized","processing","resulting","dictionary","demonstrated","transform","formulations","resonance","relatively","generalize","uncovering","relationships","community","connections","evaluat ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	nonparametrics
# 	uncoupled
# 	stochastically
# 	vertically
# 	accompanies
# 	substantive
# 	penalization
# 	neuroscientists
# 	frequentist
# 	invariances
# 	inhomogeneous
# 	overtraining
# 	integrator
# 	thermostats
# 	thermostat
# 	appropriateness
# 	emphdirectly
# 	changepoints
# 	convexification
# 	confounders
# Some words which never appear in Statistics papers:
# 	conceptualization
# 	ontological
# 	attentional
# 	experimenters
# 	pedestrian
# 	connectionist
# 	diophantine
# 	regresses
# 	appliance
# 	neighbouring
# 	devanagari
# 	lipreading
# 	subjected
# 	television
# 	abstracting
# 	temporarily
# 	orthography
# 	resourced
# 	transcriptions
# 	disciplinary

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.084040092521203e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.75
